# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv(f'D:\Data\Online Retail.csv',encoding= 'unicode_escape')

# %%
data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# ...

# %%
data.tail(10)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541899    581587     22726       ALARM CLOCK BAKELIKE GREEN         4
# 541900    581587     22730       ALARM CLOCK BAKELIKE IVORY         4
# 541901    581587     22367  CHILDRENS APRON SPACEBOY DESIGN         8
# 541902    581587     22629              SPACEBOY LUNCH BOX         12
# 541903    581587     23256      CHILDRENS CUTLERY SPACEBOY          4
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID Country
# 541899  09-12-2011 12:50       3.75     12680.0  France
# 541900  09-12-2011 12:50       3.75     12680.0  France
# ...

# %%
data.shape
# Out:
# (541909, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
print("Number of transactions :",data['InvoiceNo'].nunique())
print("Number of products :",data['StockCode'].nunique())
print("Number of Customers:",data['CustomerID'].nunique())
print("Number of countries:",data['Country'].nunique())
# Out:
# Number of transactions : 25900
# Number of products : 4070
# Number of Customers: 4372
# Number of countries: 38

# %%
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
print("percentage of null customer id:", round(data['CustomerID'].isnull().sum() * 100 / len(data), 3), "%")
# Out:
# percentage of null customer id: 24.927 %

# %%
data.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
cancelled_orders=data[data['InvoiceNo'].astype(str).str.contains('C')]

# %%
cancelled_orders.head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 141  01-12-2010 09:41      27.50     14527.0  United Kingdom
# 154  01-12-2010 09:49       4.65     15311.0  United Kingdom
# 235  01-12-2010 10:24       1.65     17548.0  United Kingdom
# 236  01-12-2010 10:24       0.29     17548.0  United Kingdom
# 237  01-12-2010 10:24       0.29     17548.0  United Kingdom

# %%
cancelled_orders[cancelled_orders['Quantity']==-80995]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540422   C581484     23843  PAPER CRAFT , LITTLE BIRDIE    -80995
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 540422  09-12-2011 09:27       2.08     16446.0  United Kingdom

# %%
print("total cancelled orders", len(cancelled_orders))
# Out:
# total cancelled orders 9288

# %%
total_orders=data['InvoiceNo'].nunique()
print(total_orders)
# Out:
# 25900

# %%
print("Percentage of Cancelled Orders",round((len(cancelled_orders)*100/total_orders),3),"%")
# Out:
# Percentage of Cancelled Orders 35.861 %

# %%
data['Total_cost']=data['UnitPrice']*data['Quantity']

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country  Total_cost
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom       15.30
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom       20.34
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom       22.00
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom       20.34
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom       20.34

# %%
# Group the data by 'Country' and sum the 'Total_cost'
country_data = data.groupby(['Country']).agg({'Total_cost': 'sum'}).sort_values(by='Total_cost', ascending=False)

# %%
country_data
# Out:
#                        Total_cost
# Country
# United Kingdom        8187806.364
# Netherlands            284661.540
# EIRE                   263276.820
# Germany                221698.210
# France                 197403.900
# Australia              137077.270
# Switzerland             56385.350
# Spain                   54774.580
# Belgium                 40910.960
# Sweden                  36595.910
# Japan                   35340.620
# Norway                  35163.460
# Portugal                29367.020
# Finland                 22326.740
# Channel Islands         20086.290
# Denmark                 18768.140
# Italy                   16890.510
# Cyprus                  12946.290
# Austria                 10154.320
# Hong Kong               10117.040
# Singapore                9120.390
# Israel                   7907.820
# Poland                   7213.140
# Unspecified              4749.790
# Greece                   4710.520
# Iceland                  4310.000
# ...

# %%
# Plot the data
ax=country_data.plot(kind='bar', figsize=(12, 6),color='teal')
plt.xlabel('Countrys')
plt.ylabel('Total Cost')
plt.title('Total Cost by Country')
# Set y-axis limits
ax.set_ylim(0, country_data['Total_cost'].max() * 1.1)

plt.show()
